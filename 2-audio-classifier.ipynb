# %%
pip install git+https://github.com/huggingface/transformers

# %%
pip install datasets==2.16.0

# %%
from datasets import load_dataset

# %% [markdown]
# # **Keyword Spotting**

# %% [markdown]
# **Minds-14**

# %%
minds = load_dataset(
    "PolyAI/minds14",
    name="en-AU",
    split="train",
    trust_remote_code=True
)

# %%
from transformers import pipeline

classifier = pipeline(
    "audio-classification",
    model="anton-l/xtreme_s_xlsr_300m_minds14",
)
# Out:
# config.json: 0.00B [00:00, ?B/s]
# pytorch_model.bin:   0%|          | 0.00/1.26G [00:00<?, ?B/s]
# model.safetensors:   0%|          | 0.00/1.26G [00:00<?, ?B/s]
# preprocessor_config.json:   0%|          | 0.00/212 [00:00<?, ?B/s]
# Device set to use cpu

# %%
classifier(minds[0]["audio"])
# Out:
# [{'score': 0.9611983895301819, 'label': 'pay_bill'},
#  {'score': 0.029602158814668655, 'label': 'freeze'},
#  {'score': 0.0035503290127962828, 'label': 'card_issues'},
#  {'score': 0.002132321475073695, 'label': 'abroad'},
#  {'score': 0.000882967549841851, 'label': 'high_value_payment'},
#  {'score': 0.0007431741687469184, 'label': 'direct_debit'},
#  {'score': 0.00041438554762862623, 'label': 'latest_transactions'},
#  {'score': 0.0003488659276627004, 'label': 'joint_account'},
#  {'score': 0.00033650899422354996, 'label': 'address'},
#  {'score': 0.0003286298015154898, 'label': 'balance'},
#  {'score': 0.00015601400809828192, 'label': 'app_error'},
#  {'score': 0.00015001874999143183, 'label': 'atm_limit'},
#  {'score': 8.98744838195853e-05, 'label': 'cash_deposit'},
#  {'score': 6.637129990849644e-05, 'label': 'business_loan'}]

# %% [markdown]
# **Speech Commands**

# %%
speech_commands = load_dataset(
    "speech_commands", "v0.02", split="validation", streaming=True
)
sample = next(iter(speech_commands))
# Out:
# /usr/local/lib/python3.11/dist-packages/datasets/load.py:1429: FutureWarning: The repository for speech_commands contains custom code which must be executed to correctly load the dataset. You can inspect the repository content at https://hf.co/datasets/speech_commands
# You can avoid this message in future by passing the argument `trust_remote_code=True`.
# Passing `trust_remote_code=True` will be mandatory to load this dataset from the next major release of `datasets`.
#   warnings.warn(
# Downloading builder script: 0.00B [00:00, ?B/s]
# Downloading readme: 0.00B [00:00, ?B/s]

# %%
classifier = pipeline(
    "audio-classification", model="MIT/ast-finetuned-speech-commands-v2"
)
classifier(sample["audio"].copy())
# Out:
# config.json: 0.00B [00:00, ?B/s]
# model.safetensors:   0%|          | 0.00/342M [00:00<?, ?B/s]
# preprocessor_config.json:   0%|          | 0.00/295 [00:00<?, ?B/s]
# Device set to use cpu
# [{'score': 0.9999892711639404, 'label': 'backward'},
#  {'score': 1.7504938796264469e-06, 'label': 'happy'},
#  {'score': 6.703040185129794e-07, 'label': 'follow'},
#  {'score': 5.805895852972753e-07, 'label': 'stop'},
#  {'score': 5.614552378574444e-07, 'label': 'up'},
#  {'score': 5.420191655503004e-07, 'label': 'four'},
#  {'score': 5.060540502199729e-07, 'label': 'nine'},
#  {'score': 4.6110199036775157e-07, 'label': 'no'},
#  {'score': 4.5555617589343456e-07, 'label': 'go'},
#  {'score': 4.081044835402281e-07, 'label': 'three'},
#  {'score': 3.192400868101686e-07, 'label': 'five'},
#  {'score': 3.080102430885745e-07, 'label': 'zero'},
#  {'score': 3.075954566611472e-07, 'label': 'two'},
#  {'score': 2.982352214075945e-07, 'label': 'down'},
#  {'score': 2.6101352545992995e-07, 'label': 'wow'},
#  {'score': 2.5764123279259366e-07, 'label': 'six'},
#  {'score': 2.5285493165938533e-07, 'label': 'off'},
#  {'score': 2.446161033731187e-07, 'label': 'seven'},
#  {'score': 2.4149224486791354e-07, 'label': 'marvin'},
#  {'score': 2.2160658375014464e-07, 'label': 'tree'},
#  {'score': 2.1947600714611326e-07, 'label': 'on'},
#  {'score': 2.1806812355862348e-07, 'label': 'one'},
#  {'score': 1.9205704404612334e-07, 'label': 'eight'},
#  {'score': 1.896244583576845e-07, 'label': 'sheila'},
#  {'score': 1.74639609440419e-07, 'label': 'visual'},
#  {'score': 1.650138585773675e-07, 'label': 'house'},
#  {'score': 1.6407609848556604e-07, 'label': 'right'},
#  {'score': 1.6359437893243012e-07, 'label': 'cat'},
#  {'score': 1.615386509001837e-07, 'label': 'forward'},
#  {'score': 1.5841223444112984e-07, 'label': 'left'},
#  {'score': 1.2257491732725612e-07, 'label': 'learn'},
#  {'score': 1.1633372309916012e-07, 'label': 'yes'},
#  {'score': 7.177735739105628e-08, 'label': 'dog'},
#  {'score': 5.5408886368013555e-08, 'label': 'bed'},
#  {'score': 5.404899994232437e-08, 'label': 'bird'}]

# %%
from IPython.display import Audio

Audio(sample["audio"]["array"], rate=sample["audio"]["sampling_rate"])
# Out:
#                 <audio  controls="controls" >
#                     <source src="data:audio/wav;base64,..." type="audio/wav" />
#                     Your browser does not support the audio element.
#                 </audio>

# %% [markdown]
# # **Language Identification**
# **FLEURS**

# %%
fleurs = load_dataset("google/fleurs", "all", split="validation", streaming=True)
sample = next(iter(fleurs))
# Out:
# /usr/local/lib/python3.11/dist-packages/huggingface_hub/utils/_auth.py:94: UserWarning:
# The secret `HF_TOKEN` does not exist in your Colab secrets.
# To authenticate with the Hugging Face Hub, create a token in your settings tab (https://huggingface.co/settings/tokens), set it as secret in your Google Colab and restart your session.
# You will be able to reuse this secret in all of your notebooks.
# Please note that authentication is recommended but still optional to access public models or datasets.
#   warnings.warn(
# /usr/local/lib/python3.11/dist-packages/datasets/load.py:1429: FutureWarning: The repository for google/fleurs contains custom code which must be executed to correctly load the dataset. You can inspect the repository content at https://hf.co/datasets/google/fleurs
# You can avoid this message in future by passing the argument `trust_remote_code=True`.
# Passing `trust_remote_code=True` will be mandatory to load this dataset from the next major release of `datasets`.
#   warnings.warn(
# Downloading builder script: 0.00B [00:00, ?B/s]
# Downloading readme: 0.00B [00:00, ?B/s]

# %%
from transformers import pipeline
classifier = pipeline(
    "audio-classification", model="sanchit-gandhi/whisper-medium-fleurs-lang-id"
)
# Out:
# config.json: 0.00B [00:00, ?B/s]
# model.safetensors:   0%|          | 0.00/615M [00:00<?, ?B/s]
# preprocessor_config.json:   0%|          | 0.00/339 [00:00<?, ?B/s]
# Device set to use cpu

# %%
classifier(sample["audio"])
# Out:
# [{'score': 1.0, 'label': 'Afrikaans'},
#  {'score': 7.092952728271484e-06, 'label': 'Northern-Sotho'},
#  {'score': 4.291534423828125e-06, 'label': 'Icelandic'},
#  {'score': 3.2782554626464844e-06, 'label': 'Danish'},
#  {'score': 3.2782554626464844e-06, 'label': 'Cantonese Chinese'},
#  {'score': 3.2186508178710938e-06, 'label': 'Luxembourgish'},
#  {'score': 3.159046173095703e-06, 'label': 'Tamil'},
#  {'score': 3.039836883544922e-06, 'label': 'Uzbek'},
#  {'score': 3.039836883544922e-06, 'label': 'Bengali'},
#  {'score': 2.9206275939941406e-06, 'label': 'Maltese'},
#  {'score': 1.6093254089355469e-06, 'label': 'Kazakh'},
#  {'score': 1.3709068298339844e-06, 'label': 'Oromo'},
#  {'score': 1.2516975402832031e-06, 'label': 'Polish'},
#  {'score': 1.1920928955078125e-06, 'label': 'English'},
#  {'score': 1.0728836059570312e-06, 'label': 'Dutch'},
#  {'score': 1.0132789611816406e-06, 'label': 'Estonian'},
#  {'score': 9.5367431640625e-07, 'label': 'Belarusian'},
#  {'score': 8.940696716308594e-07, 'label': 'Marathi'},
#  {'score': 8.940696716308594e-07, 'label': 'Zulu'},
#  {'score': 8.940696716308594e-07, 'label': 'Greek'},
#  {'score': 8.344650268554688e-07, 'label': 'Sorani-Kurdish'},
#  {'score': 7.748603820800781e-07, 'label': 'Russian'},
#  {'score': 7.748603820800781e-07, 'label': 'Vietnamese'},
#  {'score': 7.748603820800781e-07, 'label': 'Bosnian'},
#  {'score': 7.152557373046875e-07, 'label': 'Czech'},
#  {'score': 7.152557373046875e-07, 'label': 'Macedonian'},
#  {'score': 7.152557373046875e-07, 'label': 'Asturian'},
#  {'score': 6.556510925292969e-07, 'label': 'Maori'},
#  {'score': 5.960464477539062e-07, 'label': 'Galician'},
#  {'score': 5.960464477539062e-07, 'label': 'Xhosa'},
#  {'score': 5.960464477539062e-07, 'label': 'Welsh'},
#  {'score': 5.364418029785156e-07, 'label': 'Irish'},
#  {'score': 5.364418029785156e-07, 'label': 'Finnish'},
#  {'score': 5.364418029785156e-07, 'label': 'Armenian'},
#  {'score': 5.364418029785156e-07, 'label': 'Wolof'},
#  {'score': 5.364418029785156e-07, 'label': 'Umbundu'},
#  {'score': 4.76837158203125e-07, 'label': 'Romanian'},
#  {'score': 4.76837158203125e-07, 'label': 'Serbian'},
#  {'score': 4.172325134277344e-07, 'label': 'Slovak'},
#  {'score': 4.172325134277344e-07, 'label': 'Korean'},
#  {'score': 4.172325134277344e-07, 'label': 'Malayalam'},
#  {'score': 4.172325134277344e-07, 'label': 'Spanish'},
#  {'score': 4.172325134277344e-07, 'label': 'Ukrainian'},
#  {'score': 4.172325134277344e-07, 'label': 'German'},
#  {'score': 4.172325134277344e-07, 'label': 'Nyanja'},
#  {'score': 4.172325134277344e-07, 'label': 'Hebrew'},
#  {'score': 3.5762786865234375e-07, 'label': 'Tajik'},
#  {'score': 3.5762786865234375e-07, 'label': 'Igbo'},
#  {'score': 3.5762786865234375e-07, 'label': 'Amharic'},
#  {'score': 2.980232238769531e-07, 'label': 'Croatian'},
#  {'score': 2.980232238769531e-07, 'label': 'Kannada'},
#  {'score': 2.980232238769531e-07, 'label': 'Portuguese'},
#  {'score': 2.980232238769531e-07, 'label': 'Fula'},
#  {'score': 2.980232238769531e-07, 'label': 'Latvian'},
#  {'score': 2.980232238769531e-07, 'label': 'Thai'},
#  {'score': 2.980232238769531e-07, 'label': 'Bulgarian'},
#  {'score': 2.980232238769531e-07, 'label': 'Persian'},
#  {'score': 2.980232238769531e-07, 'label': 'Filipino'},
#  {'score': 2.980232238769531e-07, 'label': 'Somali'},
#  {'score': 2.384185791015625e-07, 'label': 'Punjabi'},
#  {'score': 2.384185791015625e-07, 'label': 'Swedish'},
#  {'score': 1.7881393432617188e-07, 'label': 'Italian'},
#  {'score': 1.7881393432617188e-07, 'label': 'Shona'},
#  {'score': 1.7881393432617188e-07, 'label': 'Javanese'},
#  {'score': 1.7881393432617188e-07, 'label': 'Luo'},
#  {'score': 1.7881393432617188e-07, 'label': 'Telugu'},
#  {'score': 1.1920928955078125e-07, 'label': 'Hungarian'},
#  {'score': 1.1920928955078125e-07, 'label': 'Hausa'},
#  {'score': 1.1920928955078125e-07, 'label': 'Kamba'},
#  {'score': 1.1920928955078125e-07, 'label': 'Turkish'},
#  {'score': 1.1920928955078125e-07, 'label': 'Mandarin Chinese'},
#  {'score': 1.1920928955078125e-07, 'label': 'Indonesian'},
#  {'score': 1.1920928955078125e-07, 'label': 'Cebuano'},
#  {'score': 1.1920928955078125e-07, 'label': 'Catalan'},
#  {'score': 1.1920928955078125e-07, 'label': 'Mongolian'},
#  {'score': 1.1920928955078125e-07, 'label': 'Georgian'},
#  {'score': 1.1920928955078125e-07, 'label': 'Kabuverdianu'},
#  {'score': 1.1920928955078125e-07, 'label': 'Lao'},
#  {'score': 1.1920928955078125e-07, 'label': 'Ganda'},
#  {'score': 5.960464477539063e-08, 'label': 'Lithuanian'},
#  {'score': 5.960464477539063e-08, 'label': 'Malay'},
#  {'score': 5.960464477539063e-08, 'label': 'Japanese'},
#  {'score': 5.960464477539063e-08, 'label': 'Assamese'},
#  {'score': 5.960464477539063e-08, 'label': 'Nepali'},
#  {'score': 5.960464477539063e-08, 'label': 'Oriya'},
#  {'score': 5.960464477539063e-08, 'label': 'Burmese'},
#  {'score': 5.960464477539063e-08, 'label': 'Occitan'},
#  {'score': 5.960464477539063e-08, 'label': 'French'},
#  {'score': 5.960464477539063e-08, 'label': 'Khmer'},
#  {'score': 5.960464477539063e-08, 'label': 'Kyrgyz'},
#  {'score': 5.960464477539063e-08, 'label': 'Slovenian'},
#  {'score': 5.960464477539063e-08, 'label': 'Swahili'},
#  {'score': 5.960464477539063e-08, 'label': 'Urdu'},
#  {'score': 5.960464477539063e-08, 'label': 'Azerbaijani'},
#  {'score': 5.960464477539063e-08, 'label': 'Arabic'},
#  {'score': 5.960464477539063e-08, 'label': 'Pashto'},
#  {'score': 0.0, 'label': 'Sindhi'},
#  {'score': 0.0, 'label': 'Gujarati'},
#  {'score': 0.0, 'label': 'Yoruba'},
#  {'score': 0.0, 'label': 'Lingala'},
#  {'score': 0.0, 'label': 'Hindi'},
#  {'score': 0.0, 'label': 'Norwegian'}]

# %% [markdown]
# # **Zero-Shot Audio Classification**

# %%
dataset = load_dataset("ashraq/esc50", split="train", streaming=True)
audio_sample = next(iter(dataset))["audio"]["array"]
# Out:
# Downloading readme:   0%|          | 0.00/345 [00:00<?, ?B/s]
# Repo card metadata block was not found. Setting CardData to empty.
# WARNING:huggingface_hub.repocard:Repo card metadata block was not found. Setting CardData to empty.
# Downloading metadata: 0.00B [00:00, ?B/s]

# %%
candidate_labels = ["Sound of a dog", "Sound of vacuum cleaner"]

# %%
classifier = pipeline(
    task="zero-shot-audio-classification", model="laion/clap-htsat-unfused"
)
classifier(audio_sample, candidate_labels=candidate_labels)
# Out:
# config.json: 0.00B [00:00, ?B/s]
# pytorch_model.bin:   0%|          | 0.00/615M [00:00<?, ?B/s]
# model.safetensors:   0%|          | 0.00/614M [00:00<?, ?B/s]
# tokenizer_config.json:   0%|          | 0.00/384 [00:00<?, ?B/s]
# vocab.json: 0.00B [00:00, ?B/s]
# merges.txt: 0.00B [00:00, ?B/s]
# tokenizer.json: 0.00B [00:00, ?B/s]
# special_tokens_map.json:   0%|          | 0.00/280 [00:00<?, ?B/s]
# preprocessor_config.json:   0%|          | 0.00/541 [00:00<?, ?B/s]
# Device set to use cpu
# [{'score': 0.9997242093086243, 'label': 'Sound of a dog'},
#  {'score': 0.00027583108749240637, 'label': 'Sound of vacuum cleaner'}]

# %%
from IPython.display import Audio
Audio(audio_sample, rate=16000)
# Out:
#                 <audio  controls="controls" >
#                     <source src="data:audio/wav;base64,..." type="audio/wav" />
#                     Your browser does not support the audio element.
#                 </audio>

# %% [markdown]
# # **Fine-tuning a model for music classification**

# %% [markdown]
# **Dataset**

# %%
from datasets import load_dataset

gtzan = load_dataset("marsyas/gtzan", "all", trust_remote_code=True)
gtzan

# %%
gtzan = gtzan["train"].train_test_split(seed=42, shuffle=True, test_size=0.1)
gtzan
# Out:
# DatasetDict({
#     train: Dataset({
#         features: ['file', 'audio', 'genre'],
#         num_rows: 899
#     })
#     test: Dataset({
#         features: ['file', 'audio', 'genre'],
#         num_rows: 100
#     })
# })

# %%
gtzan["train"][0]
# Out:
# {'file': '/root/.cache/huggingface/datasets/downloads/extracted/5022b0984afa7334ff9a3c60566280b08b5179d4ac96a628052bada7d8940244/genres/pop/pop.00098.wav',
#  'audio': {'path': '/root/.cache/huggingface/datasets/downloads/extracted/5022b0984afa7334ff9a3c60566280b08b5179d4ac96a628052bada7d8940244/genres/pop/pop.00098.wav',
#   'array': array([ 0.10720825,  0.16122437,  0.28585815, ..., -0.22924805,
#          -0.20629883, -0.11334229]),
#   'sampling_rate': 22050},
#  'genre': 7}

# %%
id2label_fn = gtzan["train"].features["genre"].int2str
id2label_fn(gtzan["train"][0]["genre"])
# Out:
# 'pop'

# %%
import gradio as gr


def generate_audio():
    example = gtzan["train"].shuffle()[0]
    audio = example["audio"]
    return (
        audio["sampling_rate"],
        audio["array"],
    ), id2label_fn(example["genre"])


with gr.Blocks() as demo:
    with gr.Column():
        for _ in range(4):
            audio, label = generate_audio()
            output = gr.Audio(audio, label=label)

demo.launch(debug=False)
# Out:
# /usr/local/lib/python3.11/dist-packages/gradio/processing_utils.py:777: UserWarning: Trying to convert audio automatically from float64 to 16-bit int format.
#   warnings.warn(warning.format(data.dtype))
# It looks like you are running Gradio on a hosted Jupyter notebook, which requires `share=True`. Automatically setting `share=True` (you can turn this off by setting `share=False` in `launch()` explicitly).
#
# Colab notebook detected. This cell will run indefinitely so that you can see errors and logs. To turn off, set debug=False in launch().
# * Running on public URL: https://15f8015e7292cbe628.gradio.live
#
# This share link expires in 1 week. For free permanent hosting and GPU upgrades, run `gradio deploy` from the terminal in the working directory to deploy to Hugging Face Spaces (https://huggingface.co/spaces)
# <div><iframe src="https://15f8015e7292cbe628.gradio.live" width="100%" height="500" allow="autoplay; camera; microphone; clipboard-read; clipboard-write;" frameborder="0" allowfullscreen></iframe></div>
# Keyboard interruption in main thread... closing server.
# Killing tunnel 127.0.0.1:7860 <> https://15f8015e7292cbe628.gradio.live

# %% [markdown]
# **Preprocessing the data**

# %%
from transformers import AutoFeatureExtractor

model_id = "ntu-spml/distilhubert"
feature_extractor = AutoFeatureExtractor.from_pretrained(
    model_id, do_normalize=True, return_attention_mask=True
)
# Out:
# preprocessor_config.json:   0%|          | 0.00/214 [00:00<?, ?B/s]

# %%
sampling_rate = feature_extractor.sampling_rate
sampling_rate
# Out:
# 16000

# %%
from datasets import Audio

gtzan = gtzan.cast_column("audio", Audio(sampling_rate=sampling_rate))

# %%
gtzan["train"][0]
# Out:
# {'file': '/root/.cache/huggingface/datasets/downloads/extracted/5022b0984afa7334ff9a3c60566280b08b5179d4ac96a628052bada7d8940244/genres/pop/pop.00098.wav',
#  'audio': {'path': '/root/.cache/huggingface/datasets/downloads/extracted/5022b0984afa7334ff9a3c60566280b08b5179d4ac96a628052bada7d8940244/genres/pop/pop.00098.wav',
#   'array': array([ 0.0873509 ,  0.20183384,  0.4790867 , ..., -0.18743178,
#          -0.23294401, -0.13517427]),
#   'sampling_rate': 16000},
#  'genre': 7}

# %%
import numpy as np

sample = gtzan["train"][0]["audio"]

print(f"Mean: {np.mean(sample['array']):.3}, Variance: {np.var(sample['array']):.3}")
# Out:
# Mean: 0.000185, Variance: 0.0493

# %%
inputs = feature_extractor(sample["array"], sampling_rate=sample["sampling_rate"])

print(f"inputs keys: {list(inputs.keys())}")

print(
    f"Mean: {np.mean(inputs['input_values']):.3}, Variance: {np.var(inputs['input_values']):.3}"
)
# Out:
# inputs keys: ['input_values', 'attention_mask']
# Mean: -7.45e-09, Variance: 1.0

# %%
max_duration = 30.0


def preprocess_function(examples):
    audio_arrays = [x["array"] for x in examples["audio"]]
    inputs = feature_extractor(
        audio_arrays,
        sampling_rate=feature_extractor.sampling_rate,
        max_length=int(feature_extractor.sampling_rate * max_duration),
        truncation=True,
        return_attention_mask=True,
    )
    return inputs

# %%
gtzan_encoded = gtzan.map(
    preprocess_function,
    remove_columns=["audio", "file"],
    batched=True,
    batch_size=100,
    num_proc=1,
)
gtzan_encoded
# Out:
# Map:   0%|          | 0/899 [00:00<?, ? examples/s]
# Map:   0%|          | 0/100 [00:00<?, ? examples/s]
# DatasetDict({
#     train: Dataset({
#         features: ['genre', 'input_values', 'attention_mask'],
#         num_rows: 899
#     })
#     test: Dataset({
#         features: ['genre', 'input_values', 'attention_mask'],
#         num_rows: 100
#     })
# })

# %%
gtzan_encoded = gtzan_encoded.rename_column("genre", "label")

# %%
id2label = {
    str(i): id2label_fn(i)
    for i in range(len(gtzan_encoded["train"].features["label"].names))
}
label2id = {v: k for k, v in id2label.items()}

id2label["7"]
# Out:
# 'pop'

# %% [markdown]
# **Fine-tuning the model**

# %%
from transformers import AutoModelForAudioClassification

num_labels = len(id2label)

model = AutoModelForAudioClassification.from_pretrained(
    model_id,
    num_labels=num_labels,
    label2id=label2id,
    id2label=id2label,
)
# Out:
# config.json: 0.00B [00:00, ?B/s]
# model.safetensors:   0%|          | 0.00/94.0M [00:00<?, ?B/s]
# Some weights of HubertForSequenceClassification were not initialized from the model checkpoint at ntu-spml/distilhubert and are newly initialized: ['classifier.bias', 'classifier.weight', 'projector.bias', 'projector.weight']
# You should probably TRAIN this model on a down-stream task to be able to use it for predictions and inference.

# %%
from huggingface_hub import notebook_login

notebook_login()
# Out:
# VBox(children=(HTML(value='<center> <img\nsrc=https://huggingface.co/front/assets/huggingface_logo-noborder.sv…

# %%
from transformers import TrainingArguments

model_name = model_id.split("/")[-1]
batch_size = 8
gradient_accumulation_steps = 1
num_train_epochs = 10

training_args = TrainingArguments(
    f"{model_name}-finetuned-gtzan",
    eval_strategy="epoch",
    save_strategy="epoch",
    learning_rate=5e-5,
    per_device_train_batch_size=batch_size,
    gradient_accumulation_steps=gradient_accumulation_steps,
    per_device_eval_batch_size=batch_size,
    num_train_epochs=num_train_epochs,
    warmup_ratio=0.1,
    logging_steps=5,
    load_best_model_at_end=True,
    metric_for_best_model="accuracy",
    fp16=True,
    push_to_hub=True,
)

# %%
pip install evaluate
# Out:
# Collecting evaluate
#   Downloading evaluate-0.4.5-py3-none-any.whl.metadata (9.5 kB)
# Requirement already satisfied: datasets>=2.0.0 in /usr/local/lib/python3.11/dist-packages (from evaluate) (4.0.0)
# Requirement already satisfied: numpy>=1.17 in /usr/local/lib/python3.11/dist-packages (from evaluate) (2.0.2)
# Requirement already satisfied: dill in /usr/local/lib/python3.11/dist-packages (from evaluate) (0.3.8)
# Requirement already satisfied: pandas in /usr/local/lib/python3.11/dist-packages (from evaluate) (2.2.2)
# Requirement already satisfied: requests>=2.19.0 in /usr/local/lib/python3.11/dist-packages (from evaluate) (2.32.3)
# Requirement already satisfied: tqdm>=4.62.1 in /usr/local/lib/python3.11/dist-packages (from evaluate) (4.67.1)
# Requirement already satisfied: xxhash in /usr/local/lib/python3.11/dist-packages (from evaluate) (3.5.0)
# Requirement already satisfied: multiprocess in /usr/local/lib/python3.11/dist-packages (from evaluate) (0.70.16)
# Requirement already satisfied: fsspec>=2021.05.0 in /usr/local/lib/python3.11/dist-packages (from fsspec[http]>=2021.05.0->evaluate) (2025.3.0)
# Requirement already satisfied: huggingface-hub>=0.7.0 in /usr/local/lib/python3.11/dist-packages (from evaluate) (0.34.3)
# Requirement already satisfied: packaging in /usr/local/lib/python3.11/dist-packages (from evaluate) (25.0)
# Requirement already satisfied: filelock in /usr/local/lib/python3.11/dist-packages (from datasets>=2.0.0->evaluate) (3.18.0)
# Requirement already satisfied: pyarrow>=15.0.0 in /usr/local/lib/python3.11/dist-packages (from datasets>=2.0.0->evaluate) (18.1.0)
# Requirement already satisfied: pyyaml>=5.1 in /usr/local/lib/python3.11/dist-packages (from datasets>=2.0.0->evaluate) (6.0.2)
# Requirement already satisfied: aiohttp!=4.0.0a0,!=4.0.0a1 in /usr/local/lib/python3.11/dist-packages (from fsspec[http]>=2021.05.0->evaluate) (3.12.15)
# Requirement already satisfied: typing-extensions>=3.7.4.3 in /usr/local/lib/python3.11/dist-packages (from huggingface-hub>=0.7.0->evaluate) (4.14.1)
# Requirement already satisfied: hf-xet<2.0.0,>=1.1.3 in /usr/local/lib/python3.11/dist-packages (from huggingface-hub>=0.7.0->evaluate) (1.1.7)
# Requirement already satisfied: charset-normalizer<4,>=2 in /usr/local/lib/python3.11/dist-packages (from requests>=2.19.0->evaluate) (3.4.2)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.11/dist-packages (from requests>=2.19.0->evaluate) (3.10)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.11/dist-packages (from requests>=2.19.0->evaluate) (2.5.0)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.11/dist-packages (from requests>=2.19.0->evaluate) (2025.8.3)
# Requirement already satisfied: python-dateutil>=2.8.2 in /usr/local/lib/python3.11/dist-packages (from pandas->evaluate) (2.9.0.post0)
# Requirement already satisfied: pytz>=2020.1 in /usr/local/lib/python3.11/dist-packages (from pandas->evaluate) (2025.2)
# Requirement already satisfied: tzdata>=2022.7 in /usr/local/lib/python3.11/dist-packages (from pandas->evaluate) (2025.2)
# Requirement already satisfied: aiohappyeyeballs>=2.5.0 in /usr/local/lib/python3.11/dist-packages (from aiohttp!=4.0.0a0,!=4.0.0a1->fsspec[http]>=2021.05.0->evaluate) (2.6.1)
# Requirement already satisfied: aiosignal>=1.4.0 in /usr/local/lib/python3.11/dist-packages (from aiohttp!=4.0.0a0,!=4.0.0a1->fsspec[http]>=2021.05.0->evaluate) (1.4.0)
# Requirement already satisfied: attrs>=17.3.0 in /usr/local/lib/python3.11/dist-packages (from aiohttp!=4.0.0a0,!=4.0.0a1->fsspec[http]>=2021.05.0->evaluate) (25.3.0)
# Requirement already satisfied: frozenlist>=1.1.1 in /usr/local/lib/python3.11/dist-packages (from aiohttp!=4.0.0a0,!=4.0.0a1->fsspec[http]>=2021.05.0->evaluate) (1.7.0)
# Requirement already satisfied: multidict<7.0,>=4.5 in /usr/local/lib/python3.11/dist-packages (from aiohttp!=4.0.0a0,!=4.0.0a1->fsspec[http]>=2021.05.0->evaluate) (6.6.3)
# Requirement already satisfied: propcache>=0.2.0 in /usr/local/lib/python3.11/dist-packages (from aiohttp!=4.0.0a0,!=4.0.0a1->fsspec[http]>=2021.05.0->evaluate) (0.3.2)
# Requirement already satisfied: yarl<2.0,>=1.17.0 in /usr/local/lib/python3.11/dist-packages (from aiohttp!=4.0.0a0,!=4.0.0a1->fsspec[http]>=2021.05.0->evaluate) (1.20.1)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.11/dist-packages (from python-dateutil>=2.8.2->pandas->evaluate) (1.17.0)
# Downloading evaluate-0.4.5-py3-none-any.whl (84 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 84.1/84.1 kB 2.5 MB/s eta 0:00:00
# Installing collected packages: evaluate
# Successfully installed evaluate-0.4.5

# %%
import evaluate
import numpy as np

metric = evaluate.load("accuracy")


def compute_metrics(eval_pred):
    """Computes accuracy on a batch of predictions"""
    predictions = np.argmax(eval_pred.predictions, axis=1)
    return metric.compute(predictions=predictions, references=eval_pred.label_ids)
# Out:
# Downloading builder script: 0.00B [00:00, ?B/s]

# %%
from transformers import Trainer

trainer = Trainer(
    model,
    training_args,
    train_dataset=gtzan_encoded["train"],
    eval_dataset=gtzan_encoded["test"],
    tokenizer=feature_extractor,
    compute_metrics=compute_metrics,
)

trainer.train()
# Out:
# /tmp/ipython-input-2059408770.py:3: FutureWarning: `tokenizer` is deprecated and will be removed in version 5.0.0 for `Trainer.__init__`. Use `processing_class` instead.
#   trainer = Trainer(
# wandb: Logging into wandb.ai. (Learn how to deploy a W&B server locally: https://wandb.me/wandb-server)
# wandb: You can find your API key in your browser here: https://wandb.ai/authorize?ref=models
# wandb: Paste an API key from your profile and hit enter:
#  ··········
# wandb: WARNING If you're specifying your api key in code, ensure this code is not shared publicly.
# wandb: WARNING Consider setting the WANDB_API_KEY environment variable, or running `wandb login` from the command line.
# wandb: No netrc file found, creating one.
# wandb: Appending key for api.wandb.ai to your netrc file: /root/.netrc
# wandb: Currently logged in as: martin-dornic (martin-dornic-arsonor) to https://api.wandb.ai. Use `wandb login --relogin` to force relogin
# Tracking run with wandb version 0.21.0
# Run data is saved locally in <code>/content/wandb/run-20250812_070922-tcxhoavp</code>
# Syncing run <strong><a href='https://wandb.ai/martin-dornic-arsonor/huggingface/runs/tcxhoavp' target="_blank">sleek-vortex-6</a></strong> to <a href='https://wandb.ai/martin-dornic-arsonor/huggingface' target="_blank">Weights & Biases</a> (<a href='https://wandb.me/developer-guide' target="_blank">docs</a>)<br>
#  View project at <a href='https://wandb.ai/martin-dornic-arsonor/huggingface' target="_blank">https://wandb.ai/martin-dornic-arsonor/huggingface</a>
#  View run at <a href='https://wandb.ai/martin-dornic-arsonor/huggingface/runs/tcxhoavp' target="_blank">https://wandb.ai/martin-dornic-arsonor/huggingface/runs/tcxhoavp</a>
#     <div>
#
#       <progress value='1130' max='1130' style='width:300px; height:20px; vertical-align: middle;'></progress>
#       [1130/1130 1:36:32, Epoch 10/10]
#     </div>
#     <table border="1" class="dataframe">
#   <thead>
#  <tr style="text-align: left;">
#       <th>Epoch</th>
#       <th>Training Loss</th>
#       <th>Validation Loss</th>
#       <th>Accuracy</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td>1</td>
#       <td>1.926200</td>
#       <td>1.826563</td>
#       <td>0.530000</td>
#     </tr>
#     <tr>
#       <td>2</td>
#       <td>1.161400</td>
#       <td>1.285415</td>
#       <td>0.610000</td>
#     </tr>
#     <tr>
#       <td>3</td>
#       <td>1.045200</td>
#       <td>0.977002</td>
#       <td>0.710000</td>
#     </tr>
#     <tr>
#       <td>4</td>
#       <td>0.638200</td>
#       <td>0.791628</td>
#       <td>0.740000</td>
#     </tr>
#     <tr>
#       <td>5</td>
#       <td>0.642100</td>
#       <td>0.632325</td>
#       <td>0.810000</td>
#     </tr>
#     <tr>
#       <td>6</td>
#       <td>0.406500</td>
#       <td>0.571324</td>
#       <td>0.790000</td>
#     </tr>
#     <tr>
#       <td>7</td>
#       <td>0.330800</td>
#       <td>0.571283</td>
#       <td>0.820000</td>
#     </tr>
#     <tr>
#       <td>8</td>
#       <td>0.151000</td>
#       <td>0.550360</td>
#       <td>0.820000</td>
#     </tr>
#     <tr>
#       <td>9</td>
#       <td>0.180100</td>
#       <td>0.565573</td>
#       <td>0.820000</td>
#     </tr>
#     <tr>
#       <td>10</td>
#       <td>0.093000</td>
#       <td>0.538665</td>
#       <td>0.820000</td>
#     </tr>
#   </tbody>
# </table><p>
# TrainOutput(global_step=1130, training_loss=0.7661731412716671, metrics={'train_runtime': 5842.9089, 'train_samples_per_second': 1.539, 'train_steps_per_second': 0.193, 'total_flos': 6.133988274624e+17, 'train_loss': 0.7661731412716671, 'epoch': 10.0})

# %%
kwargs = {
    "dataset_tags": "marsyas/gtzan",
    "dataset": "GTZAN",
    "model_name": f"{model_name}-finetuned-gtzan",
    "finetuned_from": model_id,
    "tasks": "audio-classification",
}

# %%
trainer.push_to_hub(**kwargs)
# Out:
# Processing Files (0 / 0)                : |          |  0.00B /  0.00B
# New Data Upload                         : |          |  0.00B /  0.00B
#   ...t-finetuned-gtzan/training_args.bin: 100%|##########| 5.37kB / 5.37kB
#   ...vents.1754982523.e864c1cfa44c.947.0: 100%|##########| 57.3kB / 57.3kB
#   ...t-finetuned-gtzan/model.safetensors:  44%|####4     | 41.8MB / 94.8MB
# CommitInfo(commit_url='https://huggingface.co/arsonor/distilhubert-finetuned-gtzan/commit/d128cfb001d587954c6206c63f6739f87f24b4cf', commit_message='End of training', commit_description='', oid='d128cfb001d587954c6206c63f6739f87f24b4cf', pr_url=None, repo_url=RepoUrl('https://huggingface.co/arsonor/distilhubert-finetuned-gtzan', endpoint='https://huggingface.co', repo_type='model', repo_id='arsonor/distilhubert-finetuned-gtzan'), pr_revision=None, pr_num=None)

# %% [markdown]
# **Build a demo with Gradio**

# %%
from transformers import pipeline

model_id = "arsonor/distilhubert-finetuned-gtzan"
pipe = pipeline("audio-classification", model=model_id)
# Out:
# /usr/local/lib/python3.11/dist-packages/huggingface_hub/utils/_auth.py:94: UserWarning:
# The secret `HF_TOKEN` does not exist in your Colab secrets.
# To authenticate with the Hugging Face Hub, create a token in your settings tab (https://huggingface.co/settings/tokens), set it as secret in your Google Colab and restart your session.
# You will be able to reuse this secret in all of your notebooks.
# Please note that authentication is recommended but still optional to access public models or datasets.
#   warnings.warn(
# config.json: 0.00B [00:00, ?B/s]
# model.safetensors:   0%|          | 0.00/94.8M [00:00<?, ?B/s]
# preprocessor_config.json:   0%|          | 0.00/212 [00:00<?, ?B/s]
# Device set to use cpu

# %%
def classify_audio(filepath):
    preds = pipe(filepath)
    outputs = {}
    for p in preds:
        outputs[p["label"]] = p["score"]
    return outputs

# %%
import gradio as gr

demo = gr.Interface(
    fn=classify_audio, inputs=gr.Audio(type="filepath"), outputs=gr.Label()
)
demo.launch(debug=False)
# Out:
# It looks like you are running Gradio on a hosted Jupyter notebook, which requires `share=True`. Automatically setting `share=True` (you can turn this off by setting `share=False` in `launch()` explicitly).
#
# Colab notebook detected. To show errors in colab notebook, set debug=True in launch()
# * Running on public URL: https://157f5f8dc484e252a2.gradio.live
#
# This share link expires in 1 week. For free permanent hosting and GPU upgrades, run `gradio deploy` from the terminal in the working directory to deploy to Hugging Face Spaces (https://huggingface.co/spaces)
# <div><iframe src="https://157f5f8dc484e252a2.gradio.live" width="100%" height="500" allow="autoplay; camera; microphone; clipboard-read; clipboard-write;" frameborder="0" allowfullscreen></iframe></div>
